# %%
import json
import requests

# %%
cookies = {
    "mid": "Y-0HTQALAAFNzm9Hr4C2rYuUcBbs",
    "ig_nrcb": "1",
    "ig_did": "D6240D5D-9489-436F-A5E2-691BAD21CB17",
    "datr": "RgftYxv3yUSz7HIAxX5e6Y55",
    "csrftoken": "sNEl62eIgXH7oKUtgNU0WbBGfGsPY01v",
    "ds_user_id": "58081174384",
    "sessionid": "58081174384%3A5SnYHYnUFjsylH%3A26%3AAYe5ypjmBF5hjqPyM5y4a3O5W_zB9F1rDjJIeTgX7g",
    "shbid": "\"1901\\05458081174384\\0541708014291:01f76398e67f0e6a1b52cde72f9d8e7ed6496aab4ce0e210e3c2dfe646d9e6e7c0954885\"",
    "shbts": "\"1676478291\\05458081174384\\0541708014291:01f7026a50a83399662d503dfbe0fd77196b51329c1bde26367df8042d6a354d385fa83a\"",
    "rur": "\"EAG\\05458081174384\\0541708014291:01f7e34d3e52af295bf1733bc89b0c0a0f92c019dba2ec5f0bcbb5b9edaf5a03e1321182\""
}

headers = {
    "authority": "www.instagram.com",
    "method": "GET",
    "path": "/api/v1/media/3035187576999415510/info/",
    "scheme": "https",
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "en-US,en;q=0.9",
    "cookie": "mid=ZIlxKgALAAFScymuGZ63XopJbgmQ; ig_did=3D7F7CB4-D713-4AC0-B289-1CB257D7146C; ig_nrcb=1; datr=KHGJZGAHYNaqVNT8a_ULEH_J; fbm_124024574287414=base_domain=.instagram.com; ds_user_id=6428581218; csrftoken=gIR0LRMzGwtZBswOMsjUFlvTtIYvHD8b; shbid=\"3375\0546428581218\0541722179524:01f7bf03213bbb4341d9674c56a9e0a9afba8b297c0b203b539d1cb258caad0f68004796\"; shbts=\"1690643524\0546428581218\0541722179524:01f76eb64bd2ceb317b4a349418d27e132a3318804e2aee69178c04bf105d635a2341552\"; sessionid=6428581218%3AA5GFgB30EGGQFW%3A22%3AAYfqioos88t3eXr5esYjwdNwlBk4Fbbe8gxZxsLiEQ; fbsr_124024574287414=znPQr0wyBAIAxlM4QRTCg6XlAwAEpEVKEcib0pCoZBo....; rur=\"PRN\0546428581218\0541722284934:01f79e3bcaa88bdf5ce98bcc47d3942a2d06fe8091403c2aedef8d66cbeec137c68f75c8\"",
    "referer": "https://www.instagram.com/reel/CofJwUpuo7W/",
    "sec-ch-prefers-color-scheme": "light",
    "sec-ch-ua": "\"Not?A_Brand\";v=\"8\", \"Chromium\";v=\"108\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    "viewport-width": "1280",
    "x-asbd-id": "198387",
    "x-csrftoken": "sNEl62eIgXH7oKUtgNU0WbBGfGsPY01v",
    "x-ig-app-id": "936619743392459",
    "x-ig-www-claim": "0",
    "x-requested-with": "XMLHttpRequest",
}


req = requests.get("https://www.instagram.com/api/v1/media/3035187576999415510/info/",cookies = cookies,headers = headers)

# %%
req.text
# Out:
# '{"items":[{"taken_at":1676042634,"pk":"3035187576999415510","id":"3035187576999415510_50175236894","device_timestamp":1676042560550614,"client_cache_key":"MzAzNTE4NzU3Njk5OTQxNTUxMA==.2","filter_type":0,"caption_is_edited":false,"like_and_view_counts_disabled":false,"is_reshare_of_text_post_app_media_in_ig":false,"media_type":2,"code":"CofJwUpuo7W","can_viewer_reshare":true,"caption":{"did_report_as_spam":false,"share_enabled":false,"user":{"has_anonymous_profile_picture":false,"fan_club_info":{"fan_club_id":null,"fan_club_name":null,"is_fan_club_referral_eligible":null,"fan_consideration_page_revamp_eligiblity":null,"is_fan_club_gifting_eligible":null,"subscriber_count":null,"connected_member_count":null,"autosave_to_exclusive_highlight":null,"has_enough_subscribers_for_ssc":null},"fbid_v2":"17841450306821904","transparency_product_enabled":false,"latest_reel_media":0,"hd_profile_pic_url_info":{"url":"https://instagram.fdac27-2.fna.fbcdn.net/v/t51.2885-19/331361434_592957522826276_
# ...

# %%
req2 = requests.get("https://graph.facebook.com/v17.0/3035187576999415510/insights?metric=likes&access_token=698248005298684|7s4uz1qv7rJdN_GJ02UndGVPNeQ")

# %%
req2.text
# Out:
# '{"error":{"message":"Unsupported get request. Object with ID \'3035187576999415510\' does not exist, cannot be loaded due to missing permissions, or does not support this operation. Please read the Graph API documentation at https:\\/\\/developers.facebook.com\\/docs\\/graph-api","type":"GraphMethodException","code":100,"error_subcode":33,"fbtrace_id":"Acb4tI7V4fRJ_3EWW32jOBu"}}'
