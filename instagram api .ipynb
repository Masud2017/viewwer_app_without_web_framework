# %%
import json
import requests

# %%
cookies = {
    "mid": "Y-0HTQALAAFNzm9Hr4C2rYuUcBbs",
    "ig_nrcb": "1",
    "ig_did": "D6240D5D-9489-436F-A5E2-691BAD21CB17",
    "datr": "RgftYxv3yUSz7HIAxX5e6Y55",
    "csrftoken": "sNEl62eIgXH7oKUtgNU0WbBGfGsPY01v",
    "ds_user_id": "58081174384",
    "sessionid": "58081174384%3A5SnYHYnUFjsylH%3A26%3AAYe5ypjmBF5hjqPyM5y4a3O5W_zB9F1rDjJIeTgX7g",
    "shbid": "\"1901\\05458081174384\\0541708014291:01f76398e67f0e6a1b52cde72f9d8e7ed6496aab4ce0e210e3c2dfe646d9e6e7c0954885\"",
    "shbts": "\"1676478291\\05458081174384\\0541708014291:01f7026a50a83399662d503dfbe0fd77196b51329c1bde26367df8042d6a354d385fa83a\"",
    "rur": "\"EAG\\05458081174384\\0541708014291:01f7e34d3e52af295bf1733bc89b0c0a0f92c019dba2ec5f0bcbb5b9edaf5a03e1321182\""
}

headers = {
    "authority": "www.instagram.com",
    "method": "GET",
    "path": "/api/v1/media/3033137866545317138/info/",
    "scheme": "https",
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "en-US,en;q=0.9",
    "cookie": "mid=ZIlxKgALAAFScymuGZ63XopJbgmQ; ig_did=3D7F7CB4-D713-4AC0-B289-1CB257D7146C; ig_nrcb=1; datr=KHGJZGAHYNaqVNT8a_ULEH_J; fbm_124024574287414=base_domain=.instagram.com; ds_user_id=6428581218; csrftoken=gIR0LRMzGwtZBswOMsjUFlvTtIYvHD8b; sessionid=6428581218%3AA5GFgB30EGGQFW%3A22%3AAYfazLyUI_7iwb8A-IOttymVT7ifzhvqtSPnALDUFG4; shbid=\"3375\0546428581218\0541723136658:01f7d502488b704637c9b56ae8344379dbc500d5615381d25241dff12f4c85d87537228a\"; shbts=\"1691600658\0546428581218\0541723136658:01f7a286932db917f076d30fffdd6a4bda3052c402c1e37ca1d02995cea87ff9fe8f165a\"; fbsr_124024574287414=M1i4OW6E1KsfunLaSdCxZx8XALsrVbnB6YmxwwDX0uY....; rur=\"PRN\0546428581218\0541723136660:01f71e13eaa9cb48703a684876543c42d2ebe255257f3d63688387a1f98601635793c9b2\"",
    "referer": "https://www.instagram.com/reel/CoX3tHCOEUS/",
    "sec-ch-prefers-color-scheme": "light",
    "sec-ch-ua": "\"Not?A_Brand\";v=\"8\", \"Chromium\";v=\"108\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    "viewport-width": "1280",
    "x-asbd-id": "198387",
    
    "x-ig-app-id": "936619743392459",
    "x-ig-www-claim": "0",
    "x-requested-with": "XMLHttpRequest",
}


req = requests.get("https://www.instagram.com/api/v1/media/3033137866545317138/info/",headers = headers)

# %%
req.text
# Out:
# '{"items":[{"taken_at":1675798200,"pk":"3033137866545317138","id":"3033137866545317138_50175236894","device_timestamp":1675798200,"client_cache_key":"MzAzMzEzNzg2NjU0NTMxNzEzOA==.2","filter_type":0,"caption_is_edited":false,"like_and_view_counts_disabled":false,"is_reshare_of_text_post_app_media_in_ig":false,"media_type":2,"code":"CoX3tHCOEUS","can_viewer_reshare":true,"caption":{"did_report_as_spam":false,"is_covered":false,"is_ranked_comment":false,"media_id":"3033137866545317138","pk":"17989634473794274","user_id":"50175236894","user":{"has_anonymous_profile_picture":false,"fan_club_info":{"fan_club_id":null,"fan_club_name":null,"is_fan_club_referral_eligible":null,"fan_consideration_page_revamp_eligiblity":null,"is_fan_club_gifting_eligible":null,"subscriber_count":null,"connected_member_count":null,"autosave_to_exclusive_highlight":null,"has_enough_subscribers_for_ssc":null},"fbid_v2":"17841450306821904","transparency_product_enabled":false,"latest_reel_media":1691597945,"hd_pro
# ...

# %%
# code for geting media id from a short code . This is important for constructing url like : /api/v1/media/media_id/info
def shortcode_to_mediaid(shortcode):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789-_'
    mediaid = 0
    
    for letter in shortcode:
        mediaid = (mediaid * 64) + alphabet.index(letter)
    
    return mediaid

# %%
shortcode_to_mediaid("CoX3tHCOEUS")
# Out:
# 3033137866545317138
